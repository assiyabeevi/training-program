# %% [markdown]
# <a href="https://colab.research.google.com/github/assiyabeevi/training-program/blob/main/pythonclass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=int(input("enter number of monkeys:"))
k=int(input("enter bananas per monkey"))
j=int(input("enter peanuts per monkey:"))
m=int(input("enter total bananas"))
p=int(input("enter total peanuts"))
monkeys=0
if m >= k:
  monkeys = monkeys+(m//k)
  m = m % k
if p>j:
  monkeys = monkeys+(p//j)
  p = p % j
if m>0 and p>0 and monkeys <n:
  monkeys = monkeys+1
if monkeys > n:
    monkeys = n
remaining = n-monkeys
print("remainig monkeys:",remaining)
# Out:
# enter number of monkeys:20
# enter bananas per monkey2
# enter peanuts per monkey:3
# enter total bananas12
# enter total peanuts12
# remainig monkeys: 10

# %%
a = int(input("enter first number:"))
b = int(input("enter second number:"))
a = a + b
b = a - b
a = a - b
print("after swapping:")
print("a =",a)
print("b =",b)
# Out:
# enter first number:7
# enter second number:5
# after swapping:
# a = 5
# b = 7

# %%
a = int(input("enter first number:"))
b = int(input("enter second number:"))
a = a ^ b
b = a ^ b
a = a ^ b
print("after swapping:")
print("a =",a)
print("a =",b)
# Out:
# enter first number:2
# enter second number:5
# after swapping:
# a = 5
# a = 2

# %%
a = int(input("enter first number:"))
b = int(input("enter second number:"))
temp = a
a = b
b = temp
print("after swapping:")
print("a =",a)
print("b =",b)
# Out:
# enter first number:8
# enter second number:4
# after swapping:
# a = 4
# b = 8

# %%
a = int(input("enter first number:"))
b = int(input("enter second number:"))
a,b = b,a
print("after swapping:")
print("a =",a)
print("a =",b)
# Out:
# enter first number:9
# enter second number:6
# after swapping:
# a = 6
# a = 9

# %%
n = 10
k = 5
candy = int(input("enter candies:"))
if candy > n:
  print("invalid input")
else:
  n = n - candy
  print("number of candies sold:",c)
  print("number of candies available:",n)
  if n <= k:
     n = 10
     print("jar refilled")
     print("number of candies available:",n)
# Out:
# enter candies:3
# number of candies sold: 13
# number of candies available: 7
